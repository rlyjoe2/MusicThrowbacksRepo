# %% [markdown]
# # **[Github](https://github.com/rlyjoe2/MusicThrowbacksRepo)**
#
#
# # **Project Introduction**
#   > Our project aims to harness the power of data science to predict song popularity. In an era where music streaming is dominant, understanding the factors that contribute to a song's success is more crucial than ever.
#   > Our approach involves analyzing the top 100 songs of each year and enriching this data with additional information from the Spotify API.
#
# ## **Objective**
#   > We aim to create a predictive model capable of forecasting a song's popularity based on various musical and metadata characteristics.
#
# ## **Method**
#     1. Data Collection: Compiling the top 100 songs annually.
#     2. Data Enrichment: Supplementing this list with detailed data from the Spotify API, including audio features and metadata.
#     3. Analysis and Model Development: Conducting data analysis, feature engineering, and applying machine learning algorithms to develop a predictive model.
#     4. Evaluation: Assessing the model's accuracy and optimizing its performance.

# %% [markdown]
# # **Changes**
# >We have changed the scope of our data to include dates farther back than we had before spanning to the 1960's.

# %% [markdown]
# # **Data**
# > We first web scrapped our data from an online source to get the top 100 songs for each year. Then, we took that data that we aquired to get more characteristics from the spotify API. Finally, we took out any outliers from the characteristics that were either unusable or we found to be not important while creating our visualizations.

# %% [markdown]
# # **[Exploratory Data Analysis](https://colab.research.google.com/drive/1I8xO9Krj2Za6m-K8pdDpULeeu2qS_nQH)**
# Our EDA has multiple components which includes:
# *   .describe() function calls on our dataframe
# *   Areas pinpointed for data correction and applying meaningful fixes(changing duration column entries from milliseconds to seconds)
# *   Exhaustively produced scatter plots showing the correlation between popularity and various audio features for each year from 2006 to 2022
# *Line plots on filtered data sets showing the average values of various audio features for the top 25 tracks of each year.
#
# During our EDA we found that some columns that had distinct clusters and there are some that have binary values. We then focus our efforts on the attributes that had clusters where we can extract meaningful insights. The below graphs are examples of data that we used to determine which attributes to focus on.
#
# Our new columns of instrest became be danceability, duration, loudness, speechiness, acousticness, valence, tempo.
#
# Instrumentalness and timeSig were removed during our EDA.
#
# It is interesting to note that genre isn't part of the track metrics for our current data set.
#
# ![acousticness_EDA.png](data:image/png;base64,...)
#
# This is a graph of popularity vs acousticness. We used this to discover relationships between popularity and the level of acousticness in relation to top hit songs.
#
# ![timeSig_EDA.png](data:image/png;base64,...)
#
# Plots by ELijah Parr
#
# # **[Hypothesis Testing](https://colab.research.google.com/drive/1-pSyvMzGUIk8eZfDmatJ2Z3Wy96x0Q3k)**
# The following definitions are taken directly from the [Spotify Developers Documentation page](https://developer.spotify.com/documentation/web-api/reference/get-audio-features):
#
#
# *   **Danceability**: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# *   **Energy**: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# *   **Valence**: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# Based on these 3 features being measures from 0.0-1.0, and obvious assumptions of relatedness one can feasibly draw between the 3, our group formed the following hypothesis:
#
# * **Valence, Energy, and Danceability share a strong correlation with one another when looking at songs in the Billboard Hot 100 from 2006-2022**
#
# View the hyperlink attached to **Hypothesis Testing** for more insights into this

# %% [markdown]
# # **Visualizations**
# ![tempavgs.png](data:image/png;base64,...)
#
# For this graph we compared the average tempo over the years from 2006-2022 and found that the average tempo is around 123 David and Elijah
#
# ![durationavgs.png](data:image/png;base64,...)
#
# David and Elijah
#
# ![duration2022avgs.png](data:image/png;base64,...)
#
# David and Elijah
#
# ![correlationmatrix.png](data:image/png;base64,...)
#
# Ryan
#
# ![avalenceenergydanceabilityavgs.png](data:image/png;base64,...)
#
# Anthony Munoz

# %% [markdown]
# # **Machine Learning Analyses**

# %% [markdown]
# # **Reflection**
# #### ○ What is the most challenging part of the project that you’ve encountered so far?
# > We have noticed that building the ML algorithm and the analysis to be the most difficult part of this project so far. We agree on this collectively as there were many steps into making the algorithm and motifying it's training data to get a model accuracy and precision that is better than ok.
#
# #### ○ What are your initial insights?
# > We have noticed when plotting the characteristics compared to popularity (i.e Popularity vs. Danceability) that there were many clusters among many of the groups and that a kmeans clustering could be a potential way to figure out what upcoming songs may be top hits. We also saw that some of the data had to be configured for a more human readible experience (i.e changing duration from milliseconds to seconds) and to also not include points such as instrumentalness as the value ranged from 0-1 with many being thousandths behind the decimal point.
#
# #### ○ Are there any concrete results you can show at this point? If not, why not?
# > We are able to show the average popularity of songs between a number of years utalizing the Vega-lite library. It will allow to visualize the average of characteristics compared to popularity across however many years the user would like to see ranging from 2006-2022.
#
# #### ○ Going forward, what are the current biggest problems you’re facing?
# >One problem that arose with our data that we have discussed with the professor is we are lacking in the amount of data as we are comparing the popularity of music to characteristics over the years and having data only from 2006-2022 is not enough. We also have a problem of determining clear and concise hypothesis as currently some of our hypothesis lack clarity and concrete evidence to back them up.
#
# #### ○ Do you think you are on track with your project? If not, what parts do you need to dedicate more time to?
# >Our group believes that we are on track with our project and have worked diligently to get to this point. We obviously need to gather more data as mentioned above to have better visualizations and training data to determine the next big hit song, but otherwise, we have agreed that we are on track.
#
# #### ○ Given your initial exploration of the data, is it worth proceeding with your project, why? If not, how will you move forward (method, data etc)?
# > Given our inital exploration we are confident that we will be proceeding with this project as there is a lot of data to work with and many hypothesis we can make moving forward.

# %% [markdown]
# # **What's next?**
# >We would like to get more data spanning as far back as the 1960's to better train our data and to also provide visualizations for our project. This will involve web scrapping more data from another site and also doing more API calls. In additon, with this new data we plan on making the visualizations more clear and aquire a better trend. We would also like to build new visualizations using this data for our final report as well.
